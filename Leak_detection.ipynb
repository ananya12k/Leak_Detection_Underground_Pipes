# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya12k/Leak_Detection_Underground_Pipes/blob/main/Leak_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.7/871.7 kB 29.1 MB/s eta 0:00:00
# ...

# %%
import os
HOME=os.getcwd()
print(HOME)
# Out:
# /content

# %%
from IPython import display
display.clear_output()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="GULd2XwyTBxpwq78xzZk")
project = rf.workspace("underwaterpipes").project("underwater_pipes_orginal_pictures")
version = project.version(3)
dataset = version.download("yolov8-obb")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Underwater_pipes_orginal_pictures-3 in yolov8-obb:: 100%|██████████| 15954/15954 [00:07<00:00, 2187.48it/s]

# %%
# %pwd
# %ls
# Out:
# Underwater_pipes_orginal_pictures-3/

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=15 imgsz=800
# Out:
# Ultralytics YOLOv8.2.89 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model={HOME}/datasets/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.2.89 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/Underwater_pipes_orginal_pictures-3/valid/labels.cache... 1575 images, 104 backgrounds, 0 corrupt: 100% 1575/1575 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 99/99 [00:21<00:00,  4.53it/s]
#                    all       1575       2430      0.987       0.99      0.994      0.923
# Speed: 0.9ms preprocess, 5.7ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect \
mode=predict \
model={HOME}/datasets/runs/detect/train2/weights/best.pt \
conf=0.1 \
iou=0.8 \
imgsz=800 \
line_width=3 \
show_labels=True \
show_conf=True \
source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.2.89 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/779 /content/datasets/Underwater_pipes_orginal_pictures-3/test/images/empty_frame00175_rrgb_jpg.rf.58308918bdf74f7dab22d1ce17f7410f.jpg: 800x800 (no detections), 13.7ms
# image 2/779 /content/datasets/Underwater_pipes_orginal_pictures-3/test/images/empty_frame00176_rrgb_jpg.rf.a5083d8065edd67ec0a88e5b47edfd37.jpg: 800x800 (no detections), 13.3ms
# image 3/779 /content/datasets/Underwater_pipes_orginal_pictures-3/test/images/empty_frame00183_rrgb_jpg.rf.4219af8931400517703837e60482e327.jpg: 800x800 (no detections), 10.8ms
# image 4/779 /content/datasets/Underwater_pipes_orginal_pictures-3/test/images/empty_frame00427_lrgb_jpg.rf.3067495704d3009a8c11f722fd4115f3.jpg: 800x800 (no detections), 9.8ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content/datasets'

# %%
# !cp -r /content/datasets/Underwater_pipes_orginal_pictures-3 /content/drive/MyDrive/Underwater_pipes_orginal_pictures-3

# %%
# !cp -r /content/datasets/runs /content/drive/MyDrive/Underwater_pipes_orginal_pictures-3/runs
